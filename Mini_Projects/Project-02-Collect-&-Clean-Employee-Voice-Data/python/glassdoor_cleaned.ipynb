# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/glassdoor_reviews - glass_reviews.csv')

# Preview the data
print(df.head())

# Get info about the columns
print(df.info())

# Check number of rows and columns
print(df.shape)

# Get statistical summary of numeric columns
print(df.describe())
# Out:
#    review_id               rating_date  count_helpful  count_unhelpful  \
# 0          1  2025-06-03T00:00:00.000Z            0.0              0.0
# 1          2  2025-05-29T00:00:00.000Z            0.0              0.0
# 2          3  2025-05-28T00:00:00.000Z            0.0              0.0
# 3          4  2025-05-26T00:00:00.000Z            0.0              0.0
# 4          5  2025-05-23T00:00:00.000Z            0.0              0.0
#
#   employee_length employee_status                       employee_type  \
# 0               0         REGULAR                    Current employee
# 1               1        CONTRACT  Current employee, less than 1 year
# 2               1         REGULAR  Current employee, less than 1 year
# 3               2       PART_TIME                   Current employees
# 4               0         REGULAR                    Current employee
#
#   flag_covid flag_featured flags_business_outlook  ...  \
# 0      False         False                    NaN  ...
# 1      False         False               POSITIVE  ...
# 2      False         False               POSITIVE  ...
# 3      False         False               POSITIVE  ...
# 4      False         False                    NaN  ...
#
#                 company_name review_advice  career_opportunities_rating  \
# 0  Amazon Fulfillment Center           NaN                          NaN
# 1  Amazon Fulfillment Center           NaN                          NaN
# 2  Amazon Fulfillment Center           NaN                          NaN
# 3  Amazon Fulfillment Center           NaN                          NaN
# 4  Amazon Fulfillment Center           NaN                          NaN
#
#    employee_location               employee_job_title  \
# 0       Richmond, VA  Warehouse Fulfillment Associate
# 1       Brampton, ON              Warehouse Associate
# 2         Bolton, ON              Warehouse Associate
# 3     Swedesboro, NJ                         Employee
# 4         Whitby, ON            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons rating_senior_leadership  \
# 0      inhumane \ndraining physically &amp; mentally                      0.0
# 1  Sticks rules and completing targets any how, o...                      3.0
# 2  limited opportunities for advancement,No clear...                      5.0
# 3                 Tough on the body\nLabor intensive                      2.0
# 4            Not hiring permanent employees directly                      0.0
#
#    rating_compensation_benefits
# 0                           0.0
# 1                           5.0
# 2                           5.0
# 3                           2.0
# 4                           0.0
#
# [5 rows x 27 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   review_id                     141 non-null    int64
#  1   rating_date                   141 non-null    object
#  2   count_helpful                 128 non-null    float64
#  3   count_unhelpful               126 non-null    float64
#  4   employee_length               136 non-null    object
#  5   employee_status               139 non-null    object
#  6   employee_type                 141 non-null    object
#  7   flag_covid                    130 non-null    object
#  8   flag_featured                 130 non-null    object
#  9   flags_business_outlook        60 non-null     object
#  10  flags_ceo_approval            62 non-null     object
#  11  flags_recommend_frend         76 non-null     object
#  12  rating_culture_values         134 non-null    float64
#  13  rating_diversity_inclusion    134 non-null    float64
#  14  rating_overall                141 non-null    int64
#  15  rating_work_life              134 non-null    float64
#  16  summary                       140 non-null    object
#  17  company_name                  141 non-null    object
#  18  review_advice                 1 non-null      object
#  19  career_opportunities_rating   9 non-null      float64
#  20  employee_location             132 non-null    object
#  21  employee_job_title            136 non-null    object
#  22  advice_to_management          43 non-null     object
#  23  review_pros                   140 non-null    object
#  24  review_cons                   141 non-null    object
#  25  rating_senior_leadership      134 non-null    float64
#  26  rating_compensation_benefits  134 non-null    float64
# dtypes: float64(8), int64(2), object(17)
# memory usage: 29.9+ KB
# None
# (141, 27)
#         review_id  count_helpful  count_unhelpful  rating_culture_values  \
# count  141.000000          128.0            126.0             134.000000
# mean    71.000000            0.0              0.0               2.216418
# std     40.847277            0.0              0.0               1.924757
# min      1.000000            0.0              0.0               0.000000
# 25%     36.000000            0.0              0.0               0.000000
# 50%     71.000000            0.0              0.0               2.000000
# 75%    106.000000            0.0              0.0               4.000000
# max    141.000000            0.0              0.0               5.000000
#
#        rating_diversity_inclusion  rating_overall  rating_work_life  \
# count                  134.000000      141.000000        134.000000
# mean                     2.574627        3.517730          2.201493
# std                      2.064293        1.192853          1.870949
# min                      0.000000        1.000000          0.000000
# 25%                      0.000000        3.000000          0.000000
# 50%                      3.000000        4.000000          2.000000
# 75%                      5.000000        4.000000          4.000000
# max                      5.000000        5.000000          5.000000
#
#        career_opportunities_rating  rating_senior_leadership  \
# count                     9.000000                134.000000
# mean                      3.888889                  2.141791
# std                       1.452966                  1.876459
# min                       1.000000                  0.000000
# 25%                       4.000000                  0.000000
# 50%                       4.000000                  2.000000
# 75%                       5.000000                  4.000000
# max                       5.000000                  5.000000
#
#        rating_compensation_benefits
# count                    134.000000
# mean                       2.656716
# std                        1.981510
# min                        0.000000
# 25%                        0.000000
# 50%                        3.000000
# 75%                        4.000000
# max                        5.000000

# %%
df['company_name'].value_counts()
# Out:
# company_name
# Amazon Fulfillment Center    126
# AFC                           15
# Name: count, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# review_advice                   140
# career_opportunities_rating     132
# advice_to_management             98
# flags_business_outlook           81
# flags_ceo_approval               79
# flags_recommend_frend            65
# count_unhelpful                  15
# count_helpful                    13
# flag_featured                    11
# flag_covid                       11
# employee_location                 9
# rating_senior_leadership          7
# rating_compensation_benefits      7
# rating_diversity_inclusion        7
# rating_culture_values             7
# rating_work_life                  7
# employee_length                   5
# employee_job_title                5
# employee_status                   2
# review_pros                       1
# summary                           1
# review_id                         0
# rating_date                       0
# employee_type                     0
# rating_overall                    0
# company_name                      0
# review_cons                       0
# dtype: int64

# %%
df.nunique().sort_values()
# Out:
# count_unhelpful                   1
# count_helpful                     1
# flag_covid                        1
# flag_featured                     1
# review_advice                     1
# company_name                      2
# career_opportunities_rating       4
# rating_overall                    5
# rating_senior_leadership          6
# rating_culture_values             6
# rating_diversity_inclusion        6
# rating_compensation_benefits      6
# rating_work_life                  6
# flags_recommend_frend             7
# flags_ceo_approval                8
# employee_status                   9
# employee_length                  10
# flags_business_outlook           10
# employee_type                    12
# advice_to_management             43
# employee_job_title               63
# employee_location                98
# rating_date                     103
# summary                         130
# review_pros                     139
# review_cons                     140
# review_id                       141
# dtype: int64

# %%
df = df.drop(columns=['company_name', 'count_unhelpful', 'count_helpful', 'flag_covid', 'flag_featured', 'review_advice'])

# %%
df.head()
df.isnull().sum().sort_values(ascending=False)
# Out:
# career_opportunities_rating     132
# advice_to_management             98
# flags_business_outlook           81
# flags_ceo_approval               79
# flags_recommend_frend            65
# employee_location                 9
# rating_senior_leadership          7
# rating_work_life                  7
# rating_culture_values             7
# rating_diversity_inclusion        7
# rating_compensation_benefits      7
# employee_length                   5
# employee_job_title                5
# employee_status                   2
# review_pros                       1
# summary                           1
# review_id                         0
# employee_type                     0
# rating_date                       0
# rating_overall                    0
# review_cons                       0
# dtype: int64

# %%
df = df.dropna(subset=['summary', 'employee_status', 'employee_job_title'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133 entries, 0 to 140
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   review_id                     133 non-null    int64
#  1   rating_date                   133 non-null    object
#  2   employee_length               128 non-null    object
#  3   employee_status               133 non-null    object
#  4   employee_type                 133 non-null    object
#  5   flags_business_outlook        58 non-null     object
#  6   flags_ceo_approval            61 non-null     object
#  7   flags_recommend_frend         72 non-null     object
#  8   rating_culture_values         126 non-null    float64
#  9   rating_diversity_inclusion    126 non-null    float64
#  10  rating_overall                133 non-null    int64
#  11  rating_work_life              126 non-null    float64
#  12  summary                       133 non-null    object
#  13  career_opportunities_rating   9 non-null      float64
#  14  employee_location             126 non-null    object
#  15  employee_job_title            133 non-null    object
#  16  advice_to_management          41 non-null     object
#  17  review_pros                   132 non-null    object
#  18  review_cons                   133 non-null    object
#  19  rating_senior_leadership      126 non-null    float64
#  20  rating_compensation_benefits  126 non-null    float64
# dtypes: float64(6), int64(2), object(13)
# memory usage: 22.9+ KB

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    review_id               rating_date employee_length employee_status  \
# 0          1  2025-06-03T00:00:00.000Z               0         REGULAR
# 1          2  2025-05-29T00:00:00.000Z               1        CONTRACT
# 2          3  2025-05-28T00:00:00.000Z               1         REGULAR
# 3          4  2025-05-26T00:00:00.000Z               2       PART_TIME
# 4          5  2025-05-23T00:00:00.000Z               0         REGULAR
#
#                         employee_type flags_business_outlook  \
# 0                    Current employee                    NaN
# 1  Current employee, less than 1 year               POSITIVE
# 2  Current employee, less than 1 year               POSITIVE
# 3                   Current employees               POSITIVE
# 4                    Current employee                    NaN
#
#   flags_ceo_approval flags_recommend_frend  rating_culture_values  \
# 0                NaN                   NaN                    0.0
# 1            APPROVE              POSITIVE                    5.0
# 2            APPROVE              POSITIVE                    5.0
# 3            APPROVE              POSITIVE                    2.0
# 4                NaN                   NaN                    0.0
#
#    rating_diversity_inclusion  ...  rating_work_life          summary  \
# 0                         0.0  ...               0.0           Amazon
# 1                         5.0  ...               3.0             Good
# 2                         5.0  ...               5.0  Good experience
# 3                         2.0  ...               2.0             Dhdh
# 4                         0.0  ...               0.0    Good Pay rate
#
#   career_opportunities_rating  employee_location  \
# 0                         NaN       Richmond, VA
# 1                         NaN       Brampton, ON
# 2                         NaN         Bolton, ON
# 3                         NaN     Swedesboro, NJ
# 4                         NaN         Whitby, ON
#
#                 employee_job_title  \
# 0  Warehouse Fulfillment Associate
# 1              Warehouse Associate
# 2              Warehouse Associate
# 3                         Employee
# 4            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons rating_senior_leadership  \
# 0      inhumane \ndraining physically &amp; mentally                      0.0
# 1  Sticks rules and completing targets any how, o...                      3.0
# 2  limited opportunities for advancement,No clear...                      5.0
# 3                 Tough on the body\nLabor intensive                      2.0
# 4            Not hiring permanent employees directly                      0.0
#
#    rating_compensation_benefits
# 0                           0.0
# 1                           5.0
# 2                           5.0
# 3                           2.0
# 4                           0.0
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns = ['summary'])

# %%
columns_to_process = ['flags_ceo_approval', 'flags_business_outlook', 'flags_recommend_frend', 'employee_status']

for col in columns_to_process:

    df[col] = df[col].astype(str).str.upper()

df.head()
# Out:
#    review_id               rating_date employee_length employee_status  \
# 0          1  2025-06-03T00:00:00.000Z               0         REGULAR
# 1          2  2025-05-29T00:00:00.000Z               1        CONTRACT
# 2          3  2025-05-28T00:00:00.000Z               1         REGULAR
# 3          4  2025-05-26T00:00:00.000Z               2       PART_TIME
# 4          5  2025-05-23T00:00:00.000Z               0         REGULAR
#
#                         employee_type flags_business_outlook  \
# 0                    Current employee                    NAN
# 1  Current employee, less than 1 year               POSITIVE
# 2  Current employee, less than 1 year               POSITIVE
# 3                   Current employees               POSITIVE
# 4                    Current employee                    NAN
#
#   flags_ceo_approval flags_recommend_frend  rating_culture_values  \
# 0                NAN                   NAN                    0.0
# 1            APPROVE              POSITIVE                    5.0
# 2            APPROVE              POSITIVE                    5.0
# 3            APPROVE              POSITIVE                    2.0
# 4                NAN                   NAN                    0.0
#
#    rating_diversity_inclusion  rating_overall  rating_work_life  \
# 0                         0.0               3               0.0
# 1                         5.0               4               3.0
# 2                         5.0               5               5.0
# 3                         2.0               3               2.0
# 4                         0.0               4               0.0
#
#    career_opportunities_rating employee_location  \
# 0                          NaN      Richmond, VA
# 1                          NaN      Brampton, ON
# 2                          NaN        Bolton, ON
# 3                          NaN    Swedesboro, NJ
# 4                          NaN        Whitby, ON
#
#                 employee_job_title  \
# 0  Warehouse Fulfillment Associate
# 1              Warehouse Associate
# 2              Warehouse Associate
# 3                         Employee
# 4            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons  \
# 0      inhumane \ndraining physically &amp; mentally
# 1  Sticks rules and completing targets any how, o...
# 2  limited opportunities for advancement,No clear...
# 3                 Tough on the body\nLabor intensive
# 4            Not hiring permanent employees directly
#
#    rating_senior_leadership  rating_compensation_benefits
# 0                       0.0                           0.0
# 1                       3.0                           5.0
# 2                       5.0                           5.0
# 3                       2.0                           2.0
# 4                       0.0                           0.0

# %%
df.to_csv('glassdoor_cleaned.csv', index = False)
