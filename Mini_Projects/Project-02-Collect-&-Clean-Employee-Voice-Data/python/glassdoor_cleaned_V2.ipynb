# %%
import pandas as pd

from datetime import datetime

df = pd.read_csv('/content/drive/MyDrive/glassdoor_cleaned.csv')

# %%
df.head()
# Out:
#    review_id rating_date employee_length employee_status  \
# 0          1  2025-06-03               0         REGULAR
# 1          2  2025-05-29               1        CONTRACT
# 2          3  2025-05-28               1         REGULAR
# 3          4  2025-05-26               2       PART_TIME
# 4          5  2025-05-23               0         REGULAR
#
#                         employee_type flags_business_outlook  \
# 0                    Current employee                    NaN
# 1  Current employee, less than 1 year               POSITIVE
# 2  Current employee, less than 1 year               POSITIVE
# 3                   Current employees               POSITIVE
# 4                    Current employee                    NaN
#
#   flags_ceo_approval flags_recommend_frend  rating_culture_values  \
# 0                NaN                   NaN                    0.0
# 1            APPROVE              POSITIVE                    5.0
# 2            APPROVE              POSITIVE                    5.0
# 3            APPROVE              POSITIVE                    2.0
# 4                NaN                   NaN                    0.0
#
#    rating_diversity_inclusion  ...  rating_work_life          summary  \
# 0                         0.0  ...               0.0           Amazon
# 1                         5.0  ...               3.0             Good
# 2                         5.0  ...               5.0  Good experience
# 3                         2.0  ...               2.0             Dhdh
# 4                         0.0  ...               0.0    Good Pay rate
#
#   career_opportunities_rating  employee_location  \
# 0                         NaN       Richmond, VA
# 1                         NaN       Brampton, ON
# 2                         NaN         Bolton, ON
# 3                         NaN     Swedesboro, NJ
# 4                         NaN         Whitby, ON
#
#                 employee_job_title  \
# 0  Warehouse Fulfillment Associate
# 1              Warehouse Associate
# 2              Warehouse Associate
# 3                         Employee
# 4            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons rating_senior_leadership  \
# 0      inhumane \ndraining physically &amp; mentally                      0.0
# 1  Sticks rules and completing targets any how, o...                      3.0
# 2  limited opportunities for advancement,No clear...                      5.0
# 3                 Tough on the body\nLabor intensive                      2.0
# 4            Not hiring permanent employees directly                      0.0
#
#    rating_compensation_benefits
# 0                           0.0
# 1                           5.0
# 2                           5.0
# 3                           2.0
# 4                           0.0
#
# [5 rows x 21 columns]

# %%
df['rating_date'] = pd.to_datetime(df['rating_date'], format='%Y-%m-%d')

df['rating_date'] = df['rating_date'].dt.strftime("%Y-%m-%dT%H:%M:%S.000Z")
df.head()
# Out:
#    review_id               rating_date employee_length employee_status  \
# 0          1  2025-06-03T00:00:00.000Z               0         REGULAR
# 1          2  2025-05-29T00:00:00.000Z               1        CONTRACT
# 2          3  2025-05-28T00:00:00.000Z               1         REGULAR
# 3          4  2025-05-26T00:00:00.000Z               2       PART_TIME
# 4          5  2025-05-23T00:00:00.000Z               0         REGULAR
#
#                         employee_type flags_business_outlook  \
# 0                    Current employee                    NaN
# 1  Current employee, less than 1 year               POSITIVE
# 2  Current employee, less than 1 year               POSITIVE
# 3                   Current employees               POSITIVE
# 4                    Current employee                    NaN
#
#   flags_ceo_approval flags_recommend_frend  rating_culture_values  \
# 0                NaN                   NaN                    0.0
# 1            APPROVE              POSITIVE                    5.0
# 2            APPROVE              POSITIVE                    5.0
# 3            APPROVE              POSITIVE                    2.0
# 4                NaN                   NaN                    0.0
#
#    rating_diversity_inclusion  ...  rating_work_life          summary  \
# 0                         0.0  ...               0.0           Amazon
# 1                         5.0  ...               3.0             Good
# 2                         5.0  ...               5.0  Good experience
# 3                         2.0  ...               2.0             Dhdh
# 4                         0.0  ...               0.0    Good Pay rate
#
#   career_opportunities_rating  employee_location  \
# 0                         NaN       Richmond, VA
# 1                         NaN       Brampton, ON
# 2                         NaN         Bolton, ON
# 3                         NaN     Swedesboro, NJ
# 4                         NaN         Whitby, ON
#
#                 employee_job_title  \
# 0  Warehouse Fulfillment Associate
# 1              Warehouse Associate
# 2              Warehouse Associate
# 3                         Employee
# 4            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons rating_senior_leadership  \
# 0      inhumane \ndraining physically &amp; mentally                      0.0
# 1  Sticks rules and completing targets any how, o...                      3.0
# 2  limited opportunities for advancement,No clear...                      5.0
# 3                 Tough on the body\nLabor intensive                      2.0
# 4            Not hiring permanent employees directly                      0.0
#
#    rating_compensation_benefits
# 0                           0.0
# 1                           5.0
# 2                           5.0
# 3                           2.0
# 4                           0.0
#
# [5 rows x 21 columns]

# %%
print(df['rating_date'])
# Out:
# 0      2025-06-03T00:00:00.000Z
# 1      2025-05-29T00:00:00.000Z
# 2      2025-05-28T00:00:00.000Z
# 3      2025-05-26T00:00:00.000Z
# 4      2025-05-23T00:00:00.000Z
#                  ...
# 128    2026-01-31T00:00:00.000Z
# 129    2026-01-29T00:00:00.000Z
# 130    2026-01-28T00:00:00.000Z
# 131    2026-01-28T00:00:00.000Z
# 132    2026-01-27T00:00:00.000Z
# Name: rating_date, Length: 133, dtype: object

# %%
df = df.drop(columns = ['summary'])

# %%
columns_to_process = ['flags_ceo_approval', 'flags_business_outlook', 'flags_recommend_frend', 'employee_status']

for col in columns_to_process:

    df[col] = df[col].astype(str).str.upper()

df.head()
# Out:
#    review_id               rating_date employee_length employee_status  \
# 0          1  2025-06-03T00:00:00.000Z               0         REGULAR
# 1          2  2025-05-29T00:00:00.000Z               1        CONTRACT
# 2          3  2025-05-28T00:00:00.000Z               1         REGULAR
# 3          4  2025-05-26T00:00:00.000Z               2       PART_TIME
# 4          5  2025-05-23T00:00:00.000Z               0         REGULAR
#
#                         employee_type flags_business_outlook  \
# 0                    Current employee                    NAN
# 1  Current employee, less than 1 year               POSITIVE
# 2  Current employee, less than 1 year               POSITIVE
# 3                   Current employees               POSITIVE
# 4                    Current employee                    NAN
#
#   flags_ceo_approval flags_recommend_frend  rating_culture_values  \
# 0                NAN                   NAN                    0.0
# 1            APPROVE              POSITIVE                    5.0
# 2            APPROVE              POSITIVE                    5.0
# 3            APPROVE              POSITIVE                    2.0
# 4                NAN                   NAN                    0.0
#
#    rating_diversity_inclusion  rating_overall  rating_work_life  \
# 0                         0.0               3               0.0
# 1                         5.0               4               3.0
# 2                         5.0               5               5.0
# 3                         2.0               3               2.0
# 4                         0.0               4               0.0
#
#    career_opportunities_rating employee_location  \
# 0                          NaN      Richmond, VA
# 1                          NaN      Brampton, ON
# 2                          NaN        Bolton, ON
# 3                          NaN    Swedesboro, NJ
# 4                          NaN        Whitby, ON
#
#                 employee_job_title  \
# 0  Warehouse Fulfillment Associate
# 1              Warehouse Associate
# 2              Warehouse Associate
# 3                         Employee
# 4            Fulfillment Associate
#
#                          advice_to_management  \
# 0                          don’t micro manage
# 1  Remove all attitude manager from warehouse
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                          review_pros  \
# 0  not interactive \ncan leave or take off whenev...
# 1                      good and easy work enviorment
# 2                          help to grow , good pay ,
# 3                    Plenty of work\nMeet new people
# 4  Good Holiday pay \nAdditional benefits for per...
#
#                                          review_cons  \
# 0      inhumane \ndraining physically &amp; mentally
# 1  Sticks rules and completing targets any how, o...
# 2  limited opportunities for advancement,No clear...
# 3                 Tough on the body\nLabor intensive
# 4            Not hiring permanent employees directly
#
#    rating_senior_leadership  rating_compensation_benefits
# 0                       0.0                           0.0
# 1                       3.0                           5.0
# 2                       5.0                           5.0
# 3                       2.0                           2.0
# 4                       0.0                           0.0

# %%
df.to_csv('glassdoor_cleaned_V2.csv')
